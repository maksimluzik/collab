# %% [markdown]
# Example colab

# %%
# Install the library (run once)
# !pip install -q google-generativeai

import google.generativeai as genai
from google.colab import userdata

# Set up your Gemini API key (add 'GOOGLE_API_KEY' to Colab Secrets)
genai.configure(api_key=userdata.get('GOOGLE_API_KEY'))

# Generate text
model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("What is the capital of France?")
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# /tmp/ipython-input-1362240899.py in <cell line: 0>()
#       6
#       7 # Set up your Gemini API key (add 'GOOGLE_API_KEY' to Colab Secrets)
# ----> 8 genai.configure(api_key=userdata.get('GOOGLE_API_KEY'))
#       9
#      10 # Generate text
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      64     )
#      65   if not resp:
# ---> 66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
#      68     raise SecretNotFoundError(key)
#
# TimeoutException: Requesting secret GOOGLE_API_KEY timed out. Secrets can only be fetched when running from the Colab UI.

# %%
from google.colab import drive
drive.mount('/content/drive')
